# %%
#필요한 라이브러리를 로드합니다. 
import os
import math
import numpy as np
import tensorflow as tf

from PIL import Image
import matplotlib.pyplot as plt
from skimage.io import imread
from skimage.transform import resize
from glob import glob

from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from keras import backend as K
from keras.regularizers import l2

print('Weeeee')
# Out:
# Weeeee

# %%
from albumentations import  HorizontalFlip, RandomSizedCrop, Compose, OneOf, Resize

def build_augmentation(is_train=True):
  if is_train:    # 훈련용 데이터일 경우
    return Compose([
                    HorizontalFlip(p=0.5),    # 50%의 확률로 좌우대칭
                    RandomSizedCrop(         # 50%의 확률로 RandomSizedCrop
                        min_max_height=(300, 370),
                        w2h_ratio=370/1242,
                        height=224,
                        width=224,
                        p=0.5
                        ),
                    Resize(              # 입력이미지를 224X224로 resize
                        width=224,
                        height=224
                        )
                    ])
  return Compose([      # 테스트용 데이터일 경우에는 224X224로 resize만 수행합니다. 
                Resize(
                    width=224,
                    height=224
                    )
                ])

# %%
import os

dir_path = '/Users/tori/desktop/workspace/aiffel_git/data/data_semantics/training'

augmentation = build_augmentation()
input_images = glob(os.path.join(dir_path, "image_2", "*.png"))

# 훈련 데이터셋에서 5개만 가져와 augmentation을 적용해 봅시다.  
plt.figure(figsize=(12, 20))
for i in range(5):
    image = imread(input_images[i]) 
    image_data = {"image":image}
    resized = augmentation(**image_data, is_train=False)
    processed = augmentation(**image_data)
    plt.subplot(5, 2, 2*i+1)
    plt.imshow(resized["image"])  # 왼쪽이 원본이미지
    plt.subplot(5, 2, 2*i+2)
    plt.imshow(processed["image"])  # 오른쪽이 augment된 이미지
  
plt.show()

# %%
class KittiGenerator(tf.keras.utils.Sequence):
  '''
  KittiGenerator는 tf.keras.utils.Sequence를 상속받습니다.
  우리가 KittiDataset을 원하는 방식으로 preprocess하기 위해서 Sequnce를 커스텀해 사용합니다.
  '''
  def __init__(self, 
               dir_path,
               batch_size=16,
               img_size=(224, 224, 3),
               output_size=(224, 224),
               is_train=True,
               augmentation=None):
    '''
    dir_path: dataset의 directory path입니다.
    batch_size: batch_size입니다.
    img_size: preprocess에 사용할 입력이미지의 크기입니다.
    output_size: ground_truth를 만들어주기 위한 크기입니다.
    is_train: 이 Generator가 학습용인지 테스트용인지 구분합니다.
    augmentation: 적용하길 원하는 augmentation 함수를 인자로 받습니다.
    '''
    self.dir_path = dir_path
    self.batch_size = batch_size
    self.is_train = is_train
    self.dir_path = dir_path
    self.augmentation = augmentation
    self.img_size = img_size
    self.output_size = output_size

    # load_dataset()을 통해서 kitti dataset의 directory path에서 라벨과 이미지를 확인합니다.
    self.data = self.load_dataset()

  def load_dataset(self):
    # kitti dataset에서 필요한 정보(이미지 경로 및 라벨)를 directory에서 확인하고 로드하는 함수입니다.
    # 이때 is_train에 따라 test set을 분리해서 load하도록 해야합니다.
    input_images = glob(os.path.join(self.dir_path, "image_2", "*.png"))
    label_images = glob(os.path.join(self.dir_path, "semantic", "*.png"))
    input_images.sort()
    label_images.sort()
    assert len(input_images) == len(label_images)
    data = [ _ for _ in zip(input_images, label_images)]

    if self.is_train:
      return data[:-30]
    return data[-30:]
    
  def __len__(self):
    # Generator의 length로서 전체 dataset을 batch_size로 나누고 소숫점 첫째자리에서 올림한 값을 반환합니다.
    return math.ceil(len(self.data) / self.batch_size)

  def __getitem__(self, index):
    # 입력과 출력을 만듭니다.
    # 입력은 resize및 augmentation이 적용된 input image이고 
    # 출력은 semantic label입니다.
    batch_data = self.data[
                           index*self.batch_size:
                           (index + 1)*self.batch_size
                           ]
    inputs = np.zeros([self.batch_size, *self.img_size])
    outputs = np.zeros([self.batch_size, *self.output_size])
        
    for i, data in enumerate(batch_data):
      input_img_path, output_path = data
      _input = imread(input_img_path)
      _output = imread(output_path)
      _output = (_output==7).astype(np.uint8)*1
      data = {
          "image": _input,
          "mask": _output,
          }
      augmented = self.augmentation(**data)
      inputs[i] = augmented["image"]/255
      outputs[i] = augmented["mask"]
      return inputs, outputs

  def on_epoch_end(self):
    # 한 epoch가 끝나면 실행되는 함수입니다. 학습중인 경우에 순서를 random shuffle하도록 적용한 것을 볼 수 있습니다.
    self.indexes = np.arange(len(self.data))
    if self.is_train == True :
      np.random.shuffle(self.indexes)
      return self.indexes

# %%
augmentation = build_augmentation()
test_preproc = build_augmentation(is_train=False)
        
train_generator = KittiGenerator(
    dir_path, 
    augmentation=augmentation,
)

test_generator = KittiGenerator(
    dir_path, 
    augmentation=test_preproc,
    is_train=False
)

# %% [markdown]
# [cleaner U-Net++](https://github.com/CarryHJR/Nested-UNet)

# %%
smooth = 1.
dropout_rate = 0.5
bn_axis = 3

def standard_unit(input_tensor, stage, nb_filter, kernel_size=3):

    act = 'relu'

    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_1', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(input_tensor)
    x = Dropout(dropout_rate, name='dp'+stage+'_1')(x)
    x = Conv2D(nb_filter, (kernel_size, kernel_size), activation=act, name='conv'+stage+'_2', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(x)
    x = Dropout(dropout_rate, name='dp'+stage+'_2')(x)

    return x

def U_Net(img_rows, img_cols, color_type=1, num_class=1):

    nb_filter = [32,64,128,256,512]
    act = 'relu'

    img_input = Input(shape=(img_rows, img_cols, color_type), name='main_input')

    conv1_1 = standard_unit(img_input, stage='11', nb_filter=nb_filter[0])
    pool1 = MaxPooling2D((2, 2), strides=(2, 2), name='pool1')(conv1_1)

    conv2_1 = standard_unit(pool1, stage='21', nb_filter=nb_filter[1])
    pool2 = MaxPooling2D((2, 2), strides=(2, 2), name='pool2')(conv2_1)

    conv3_1 = standard_unit(pool2, stage='31', nb_filter=nb_filter[2])
    pool3 = MaxPooling2D((2, 2), strides=(2, 2), name='pool3')(conv3_1)

    conv4_1 = standard_unit(pool3, stage='41', nb_filter=nb_filter[3])
    pool4 = MaxPooling2D((2, 2), strides=(2, 2), name='pool4')(conv4_1)

    conv5_1 = standard_unit(pool4, stage='51', nb_filter=nb_filter[4])

    up4_2 = Conv2DTranspose(nb_filter[3], (2, 2), strides=(2, 2), name='up42', padding='same')(conv5_1)
    conv4_2 = concatenate([up4_2, conv4_1], name='merge42', axis=bn_axis)
    conv4_2 = standard_unit(conv4_2, stage='42', nb_filter=nb_filter[3])

    up3_3 = Conv2DTranspose(nb_filter[2], (2, 2), strides=(2, 2), name='up33', padding='same')(conv4_2)
    conv3_3 = concatenate([up3_3, conv3_1], name='merge33', axis=bn_axis)
    conv3_3 = standard_unit(conv3_3, stage='33', nb_filter=nb_filter[2])    

    up2_4 = Conv2DTranspose(nb_filter[1], (2, 2), strides=(2, 2), name='up24', padding='same')(conv3_3)
    conv2_4 = concatenate([up2_4, conv2_1], name='merge24', axis=bn_axis)
    conv2_4 = standard_unit(conv2_4, stage='24', nb_filter=nb_filter[1])

    up1_5 = Conv2DTranspose(nb_filter[0], (2, 2), strides=(2, 2), name='up15', padding='same')(conv2_4)
    conv1_5 = concatenate([up1_5, conv1_1], name='merge15', axis=bn_axis)
    conv1_5 = standard_unit(conv1_5, stage='15', nb_filter=nb_filter[0])

    unet_output = Conv2D(num_class, (1, 1), activation='sigmoid', name='output', kernel_initializer = 'he_normal', padding='same', kernel_regularizer=l2(1e-4))(conv1_5)

    model = Model(img_input, unet_output)

    return model

# %%
# Defult U-net

def build_model(input_shape=(224, 224, 3)):
  inputs = Input(input_shape)
	
  #Contracting Path
  conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(inputs)
  conv1 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv1)
  pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
  conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool1)
  conv2 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv2)
  pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
  conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool2)
  conv3 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv3)
  pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
  conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool3)
  conv4 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv4)
  drop4 = Dropout(0.5)(conv4)
  pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)
  
  conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(pool4)  
  conv5 = Conv2D(1024, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv5)
  
  #Expanding Path
  drop5 = Dropout(0.5)(conv5)
  up6 = Conv2DTranspose(512, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(drop5)
  merge6 = concatenate([drop4,up6], axis = 3)
  conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge6)
  conv6 = Conv2D(512, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv6)
  up7 = Conv2DTranspose(256, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv6)
  merge7 = concatenate([conv3,up7], axis = 3)
  conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge7)
  conv7 = Conv2D(256, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv7)
  up8 = Conv2DTranspose(128, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv7)
  merge8 = concatenate([conv2,up8], axis = 3)
  conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge8)
  conv8 = Conv2D(128, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv8)
  up9 = Conv2DTranspose(64, 2, activation='relu', strides=(2,2), kernel_initializer='he_normal')(conv8)
  merge9 = concatenate([conv1,up9], axis = 3)
  conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(merge9)
  conv9 = Conv2D(64, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)  
  conv9 = Conv2D(2, 3, activation='relu', padding='same',kernel_initializer='he_normal')(conv9)     
  conv10 = Conv2D(1, 1, activation='sigmoid')(conv9)

  model = Model(inputs = inputs, outputs = conv10)
  return model

# %%
model_path = '/Users/tori/desktop/workspace/aiffel_git/model/GD10/seg_model_unet_500.h5'

model = U_Net(224, 224, 3)
model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy')
model.fit_generator(
     generator=train_generator,
     validation_data=test_generator,
     steps_per_epoch=len(train_generator),
     epochs=500,
 )

model.save(model_path)  #학습한 모델을 저장해 주세요.
# Out:
# Epoch 1/500
# 2021-10-27 12:39:45.576422: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 11/11 [==============================] - ETA: 0s - loss: 1.6165
# 2021-10-27 12:39:57.872145: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:112] Plugin optimizer for device_type GPU is enabled.
# 11/11 [==============================] - 13s 1s/step - loss: 1.6165 - val_loss: 1.2762
# Epoch 2/500
# 11/11 [==============================] - 12s 1s/step - loss: 1.3593 - val_loss: 1.2631
# Epoch 3/500
# 11/11 [==============================] - 12s 1s/step - loss: 1.2740 - val_loss: 1.2497
# Epoch 4/500
# 11/11 [==============================] - 12s 1s/step - loss: 1.2508 - val_loss: 1.2326
# Epoch 5/500
# 11/11 [==============================] - 12s 1s/step - loss: 1.2275 - val_loss: 1.2082
# Epoch 6/500
# 11/11 [==============================] - 12s 1s/step - loss: 1.1974 - val_loss: 1.1657
# Epoch 7/500
# 11/11 [==============================] - 12s 1s/step - loss: 1.1487 - val_loss: 1.0755
# Epoch 8/500
# 11/11 [==============================] - 12s 1s/step - loss: 1.0115 - val_loss: 0.8548
# Epoch 9/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.7689 - val_loss: 0.6130
# Epoch 10/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.6160 - val_loss: 0.5916
# Epoch 11/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5928 - val_loss: 0.5885
# Epoch 12/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5894 - val_loss: 0.5846
# Epoch 13/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5807 - val_loss: 0.5825
# Epoch 14/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5723 - val_loss: 0.5765
# Epoch 15/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5712 - val_loss: 0.5705
# Epoch 16/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5630 - val_loss: 0.5711
# Epoch 17/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5525 - val_loss: 0.5710
# Epoch 18/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5517 - val_loss: 0.5598
# Epoch 19/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5448 - val_loss: 0.5614
# Epoch 20/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5403 - val_loss: 0.5550
# Epoch 21/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5308 - val_loss: 0.5513
# Epoch 22/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5316 - val_loss: 0.5465
# Epoch 23/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5257 - val_loss: 0.5356
# Epoch 24/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5131 - val_loss: 0.5381
# Epoch 25/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5106 - val_loss: 0.5340
# Epoch 26/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5052 - val_loss: 0.5276
# Epoch 27/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.5037 - val_loss: 0.5178
# Epoch 28/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4924 - val_loss: 0.5159
# Epoch 29/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4888 - val_loss: 0.5112
# Epoch 30/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4851 - val_loss: 0.5013
# Epoch 31/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4803 - val_loss: 0.5014
# Epoch 32/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4806 - val_loss: 0.4947
# Epoch 33/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4718 - val_loss: 0.4971
# Epoch 34/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4661 - val_loss: 0.4839
# Epoch 35/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4649 - val_loss: 0.4846
# Epoch 36/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4630 - val_loss: 0.4754
# Epoch 37/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4558 - val_loss: 0.4738
# Epoch 38/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4529 - val_loss: 0.4687
# Epoch 39/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4486 - val_loss: 0.4628
# Epoch 40/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4401 - val_loss: 0.4567
# Epoch 41/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4371 - val_loss: 0.4551
# Epoch 42/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4328 - val_loss: 0.4493
# Epoch 43/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4273 - val_loss: 0.4457
# Epoch 44/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4208 - val_loss: 0.4432
# Epoch 45/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4210 - val_loss: 0.4363
# Epoch 46/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4172 - val_loss: 0.4340
# Epoch 47/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4116 - val_loss: 0.4282
# Epoch 48/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4053 - val_loss: 0.4235
# Epoch 49/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.4010 - val_loss: 0.4191
# Epoch 50/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3946 - val_loss: 0.4158
# Epoch 51/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3974 - val_loss: 0.4127
# Epoch 52/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3888 - val_loss: 0.4155
# Epoch 53/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3843 - val_loss: 0.4039
# Epoch 54/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3808 - val_loss: 0.4048
# Epoch 55/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3729 - val_loss: 0.4091
# Epoch 56/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3710 - val_loss: 0.4026
# Epoch 57/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3672 - val_loss: 0.3990
# Epoch 58/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3674 - val_loss: 0.3933
# Epoch 59/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3660 - val_loss: 0.3845
# Epoch 60/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3559 - val_loss: 0.3848
# Epoch 61/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3534 - val_loss: 0.3809
# Epoch 62/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3492 - val_loss: 0.3801
# Epoch 63/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3455 - val_loss: 0.3712
# Epoch 64/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3423 - val_loss: 0.3699
# Epoch 65/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3393 - val_loss: 0.3630
# Epoch 66/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3342 - val_loss: 0.3638
# Epoch 67/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3350 - val_loss: 0.3529
# Epoch 68/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3295 - val_loss: 0.3466
# Epoch 69/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3242 - val_loss: 0.3417
# Epoch 70/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3263 - val_loss: 0.3383
# Epoch 71/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3205 - val_loss: 0.3396
# Epoch 72/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3164 - val_loss: 0.3372
# Epoch 73/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3098 - val_loss: 0.3303
# Epoch 74/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3088 - val_loss: 0.3258
# Epoch 75/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3041 - val_loss: 0.3237
# Epoch 76/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3030 - val_loss: 0.3224
# Epoch 77/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3097 - val_loss: 0.3143
# Epoch 78/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.3009 - val_loss: 0.3115
# Epoch 79/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2925 - val_loss: 0.3099
# Epoch 80/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2915 - val_loss: 0.3078
# Epoch 81/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2925 - val_loss: 0.3063
# Epoch 82/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2872 - val_loss: 0.3030
# Epoch 83/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2813 - val_loss: 0.2998
# Epoch 84/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2768 - val_loss: 0.2971
# Epoch 85/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2751 - val_loss: 0.2924
# Epoch 86/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2725 - val_loss: 0.2895
# Epoch 87/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2706 - val_loss: 0.2856
# Epoch 88/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2671 - val_loss: 0.2828
# Epoch 89/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2644 - val_loss: 0.2803
# Epoch 90/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2605 - val_loss: 0.2781
# Epoch 91/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2533 - val_loss: 0.2761
# Epoch 92/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2541 - val_loss: 0.2732
# Epoch 93/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2522 - val_loss: 0.2713
# Epoch 94/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2485 - val_loss: 0.2685
# Epoch 95/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2480 - val_loss: 0.2674
# Epoch 96/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2429 - val_loss: 0.2647
# Epoch 97/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2407 - val_loss: 0.2619
# Epoch 98/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2392 - val_loss: 0.2607
# Epoch 99/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2389 - val_loss: 0.2553
# Epoch 100/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2411 - val_loss: 0.2531
# Epoch 101/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2397 - val_loss: 0.2505
# Epoch 102/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2304 - val_loss: 0.2480
# Epoch 103/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2290 - val_loss: 0.2464
# Epoch 104/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2261 - val_loss: 0.2449
# Epoch 105/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2245 - val_loss: 0.2435
# Epoch 106/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2230 - val_loss: 0.2396
# Epoch 107/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2232 - val_loss: 0.2377
# Epoch 108/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2329 - val_loss: 0.2353
# Epoch 109/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2217 - val_loss: 0.2332
# Epoch 110/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2188 - val_loss: 0.2310
# Epoch 111/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2178 - val_loss: 0.2286
# Epoch 112/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2145 - val_loss: 0.2264
# Epoch 113/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2080 - val_loss: 0.2244
# Epoch 114/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2087 - val_loss: 0.2216
# Epoch 115/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2049 - val_loss: 0.2201
# Epoch 116/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2049 - val_loss: 0.2195
# Epoch 117/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2083 - val_loss: 0.2175
# Epoch 118/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2040 - val_loss: 0.2148
# Epoch 119/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.2014 - val_loss: 0.2136
# Epoch 120/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1965 - val_loss: 0.2116
# Epoch 121/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1965 - val_loss: 0.2091
# Epoch 122/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1903 - val_loss: 0.2076
# Epoch 123/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1942 - val_loss: 0.2060
# Epoch 124/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1937 - val_loss: 0.2049
# Epoch 125/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1872 - val_loss: 0.2029
# Epoch 126/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1856 - val_loss: 0.2011
# Epoch 127/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1827 - val_loss: 0.1993
# Epoch 128/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1819 - val_loss: 0.1977
# Epoch 129/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1793 - val_loss: 0.1966
# Epoch 130/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1750 - val_loss: 0.1951
# Epoch 131/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1775 - val_loss: 0.1928
# Epoch 132/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1745 - val_loss: 0.1910
# Epoch 133/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1748 - val_loss: 0.1901
# Epoch 134/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1771 - val_loss: 0.1845
# Epoch 135/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1715 - val_loss: 0.1846
# Epoch 136/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1686 - val_loss: 0.1843
# Epoch 137/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1726 - val_loss: 0.1815
# Epoch 138/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1662 - val_loss: 0.1811
# Epoch 139/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1653 - val_loss: 0.1797
# Epoch 140/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1765 - val_loss: 0.1808
# Epoch 141/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1783 - val_loss: 0.1832
# Epoch 142/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1826 - val_loss: 0.1819
# Epoch 143/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1743 - val_loss: 0.1797
# Epoch 144/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1708 - val_loss: 0.1784
# Epoch 145/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1703 - val_loss: 0.1765
# Epoch 146/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1676 - val_loss: 0.1745
# Epoch 147/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1610 - val_loss: 0.1726
# Epoch 148/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1665 - val_loss: 0.1712
# Epoch 149/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1599 - val_loss: 0.1697
# Epoch 150/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1574 - val_loss: 0.1680
# Epoch 151/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1585 - val_loss: 0.1661
# Epoch 152/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1586 - val_loss: 0.1651
# Epoch 153/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1520 - val_loss: 0.1637
# Epoch 154/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1555 - val_loss: 0.1622
# Epoch 155/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1504 - val_loss: 0.1608
# Epoch 156/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1494 - val_loss: 0.1596
# Epoch 157/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1523 - val_loss: 0.1586
# Epoch 158/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1492 - val_loss: 0.1568
# Epoch 159/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1513 - val_loss: 0.1565
# Epoch 160/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1502 - val_loss: 0.1556
# Epoch 161/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1388 - val_loss: 0.1539
# Epoch 162/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1434 - val_loss: 0.1528
# Epoch 163/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1411 - val_loss: 0.1528
# Epoch 164/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1399 - val_loss: 0.1505
# Epoch 165/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1410 - val_loss: 0.1489
# Epoch 166/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1420 - val_loss: 0.1487
# Epoch 167/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1372 - val_loss: 0.1476
# Epoch 168/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1375 - val_loss: 0.1471
# Epoch 169/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1333 - val_loss: 0.1455
# Epoch 170/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1368 - val_loss: 0.1438
# Epoch 171/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1371 - val_loss: 0.1450
# Epoch 172/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1350 - val_loss: 0.1426
# Epoch 173/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1339 - val_loss: 0.1424
# Epoch 174/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1307 - val_loss: 0.1424
# Epoch 175/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1306 - val_loss: 0.1402
# Epoch 176/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1280 - val_loss: 0.1394
# Epoch 177/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1269 - val_loss: 0.1393
# Epoch 178/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1347 - val_loss: 0.1423
# Epoch 179/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1344 - val_loss: 0.1407
# Epoch 180/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1306 - val_loss: 0.1383
# Epoch 181/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1244 - val_loss: 0.1355
# Epoch 182/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1251 - val_loss: 0.1342
# Epoch 183/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1228 - val_loss: 0.1332
# Epoch 184/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1233 - val_loss: 0.1330
# Epoch 185/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1232 - val_loss: 0.1323
# Epoch 186/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1199 - val_loss: 0.1309
# Epoch 187/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1206 - val_loss: 0.1292
# Epoch 188/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1234 - val_loss: 0.1284
# Epoch 189/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1205 - val_loss: 0.1279
# Epoch 190/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1209 - val_loss: 0.1274
# Epoch 191/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1183 - val_loss: 0.1262
# Epoch 192/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1173 - val_loss: 0.1255
# Epoch 193/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1166 - val_loss: 0.1248
# Epoch 194/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1143 - val_loss: 0.1238
# Epoch 195/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1132 - val_loss: 0.1225
# Epoch 196/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1151 - val_loss: 0.1218
# Epoch 197/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1181 - val_loss: 0.1215
# Epoch 198/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1128 - val_loss: 0.1199
# Epoch 199/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1120 - val_loss: 0.1190
# Epoch 200/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1088 - val_loss: 0.1187
# Epoch 201/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1122 - val_loss: 0.1179
# Epoch 202/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1131 - val_loss: 0.1177
# Epoch 203/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1077 - val_loss: 0.1165
# Epoch 204/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1042 - val_loss: 0.1153
# Epoch 205/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1076 - val_loss: 0.1153
# Epoch 206/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1048 - val_loss: 0.1139
# Epoch 207/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1100 - val_loss: 0.1139
# Epoch 208/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1040 - val_loss: 0.1128
# Epoch 209/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1102 - val_loss: 0.1125
# Epoch 210/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1031 - val_loss: 0.1116
# Epoch 211/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1018 - val_loss: 0.1101
# Epoch 212/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1025 - val_loss: 0.1103
# Epoch 213/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1015 - val_loss: 0.1103
# Epoch 214/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1041 - val_loss: 0.1085
# Epoch 215/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1027 - val_loss: 0.1079
# Epoch 216/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1009 - val_loss: 0.1081
# Epoch 217/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1039 - val_loss: 0.1070
# Epoch 218/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0985 - val_loss: 0.1069
# Epoch 219/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0988 - val_loss: 0.1056
# Epoch 220/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.1000 - val_loss: 0.1053
# Epoch 221/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0942 - val_loss: 0.1046
# Epoch 222/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0937 - val_loss: 0.1043
# Epoch 223/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0981 - val_loss: 0.1032
# Epoch 224/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0944 - val_loss: 0.1030
# Epoch 225/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0942 - val_loss: 0.1035
# Epoch 226/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0964 - val_loss: 0.1023
# Epoch 227/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0972 - val_loss: 0.1011
# Epoch 228/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0937 - val_loss: 0.1009
# Epoch 229/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0929 - val_loss: 0.0998
# Epoch 230/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0910 - val_loss: 0.0996
# Epoch 231/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0923 - val_loss: 0.0990
# Epoch 232/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0898 - val_loss: 0.0983
# Epoch 233/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0892 - val_loss: 0.0981
# Epoch 234/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0928 - val_loss: 0.0976
# Epoch 235/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0913 - val_loss: 0.0971
# Epoch 236/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0891 - val_loss: 0.0972
# Epoch 237/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0864 - val_loss: 0.0959
# Epoch 238/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0920 - val_loss: 0.0957
# Epoch 239/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0836 - val_loss: 0.0947
# Epoch 240/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0841 - val_loss: 0.0951
# Epoch 241/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0845 - val_loss: 0.0942
# Epoch 242/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0882 - val_loss: 0.0958
# Epoch 243/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0864 - val_loss: 0.0961
# Epoch 244/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0835 - val_loss: 0.0956
# Epoch 245/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0828 - val_loss: 0.0931
# Epoch 246/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0824 - val_loss: 0.0927
# Epoch 247/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0815 - val_loss: 0.0926
# Epoch 248/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0832 - val_loss: 0.0929
# Epoch 249/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0789 - val_loss: 0.0927
# Epoch 250/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0783 - val_loss: 0.0920
# Epoch 251/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0793 - val_loss: 0.0914
# Epoch 252/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0799 - val_loss: 0.0911
# Epoch 253/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0773 - val_loss: 0.0908
# Epoch 254/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0810 - val_loss: 0.0929
# Epoch 255/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0811 - val_loss: 0.0905
# Epoch 256/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0811 - val_loss: 0.0878
# Epoch 257/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0817 - val_loss: 0.0926
# Epoch 258/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0811 - val_loss: 0.0899
# Epoch 259/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0720 - val_loss: 0.0879
# Epoch 260/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0756 - val_loss: 0.0876
# Epoch 261/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0717 - val_loss: 0.0867
# Epoch 262/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0739 - val_loss: 0.0874
# Epoch 263/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0729 - val_loss: 0.0898
# Epoch 264/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0744 - val_loss: 0.0890
# Epoch 265/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0710 - val_loss: 0.0883
# Epoch 266/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0680 - val_loss: 0.0857
# Epoch 267/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0763 - val_loss: 0.0886
# Epoch 268/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0730 - val_loss: 0.0839
# Epoch 269/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0732 - val_loss: 0.0849
# Epoch 270/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0699 - val_loss: 0.0858
# Epoch 271/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0689 - val_loss: 0.0853
# Epoch 272/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0681 - val_loss: 0.0823
# Epoch 273/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0668 - val_loss: 0.0844
# Epoch 274/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0665 - val_loss: 0.0852
# Epoch 275/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0649 - val_loss: 0.0856
# Epoch 276/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0648 - val_loss: 0.0845
# Epoch 277/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0685 - val_loss: 0.0883
# Epoch 278/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0684 - val_loss: 0.0829
# Epoch 279/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0682 - val_loss: 0.0859
# Epoch 280/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0654 - val_loss: 0.0838
# Epoch 281/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0652 - val_loss: 0.0801
# Epoch 282/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0691 - val_loss: 0.0830
# Epoch 283/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0649 - val_loss: 0.0783
# Epoch 284/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0667 - val_loss: 0.0847
# Epoch 285/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0647 - val_loss: 0.0802
# Epoch 286/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0661 - val_loss: 0.0830
# Epoch 287/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0654 - val_loss: 0.0850
# Epoch 288/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0627 - val_loss: 0.0809
# Epoch 289/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0636 - val_loss: 0.0804
# Epoch 290/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0633 - val_loss: 0.0803
# Epoch 291/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0602 - val_loss: 0.0854
# Epoch 292/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0589 - val_loss: 0.0791
# Epoch 293/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0658 - val_loss: 0.0825
# Epoch 294/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0603 - val_loss: 0.0822
# Epoch 295/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0609 - val_loss: 0.0802
# Epoch 296/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0577 - val_loss: 0.0776
# Epoch 297/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0609 - val_loss: 0.0749
# Epoch 298/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0581 - val_loss: 0.0821
# Epoch 299/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0593 - val_loss: 0.0822
# Epoch 300/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0613 - val_loss: 0.0765
# Epoch 301/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0601 - val_loss: 0.0781
# Epoch 302/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0601 - val_loss: 0.0881
# Epoch 303/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0574 - val_loss: 0.0793
# Epoch 304/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0593 - val_loss: 0.0863
# Epoch 305/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0607 - val_loss: 0.0774
# Epoch 306/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0598 - val_loss: 0.0815
# Epoch 307/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0589 - val_loss: 0.0821
# Epoch 308/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0584 - val_loss: 0.0762
# Epoch 309/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0576 - val_loss: 0.0806
# Epoch 310/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0549 - val_loss: 0.0745
# Epoch 311/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0576 - val_loss: 0.0743
# Epoch 312/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0628 - val_loss: 0.0819
# Epoch 313/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0589 - val_loss: 0.0775
# Epoch 314/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0558 - val_loss: 0.0839
# Epoch 315/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0542 - val_loss: 0.0822
# Epoch 316/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0548 - val_loss: 0.0834
# Epoch 317/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0548 - val_loss: 0.0817
# Epoch 318/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0522 - val_loss: 0.0817
# Epoch 319/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0537 - val_loss: 0.0814
# Epoch 320/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0528 - val_loss: 0.0806
# Epoch 321/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0532 - val_loss: 0.0772
# Epoch 322/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0558 - val_loss: 0.0842
# Epoch 323/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0578 - val_loss: 0.0781
# Epoch 324/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0532 - val_loss: 0.0806
# Epoch 325/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0554 - val_loss: 0.0734
# Epoch 326/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0519 - val_loss: 0.0786
# Epoch 327/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0524 - val_loss: 0.0736
# Epoch 328/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0517 - val_loss: 0.0736
# Epoch 329/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0515 - val_loss: 0.0748
# Epoch 330/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0512 - val_loss: 0.0728
# Epoch 331/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0488 - val_loss: 0.0827
# Epoch 332/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0570 - val_loss: 0.0935
# Epoch 333/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0551 - val_loss: 0.0856
# Epoch 334/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0553 - val_loss: 0.0807
# Epoch 335/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0499 - val_loss: 0.0819
# Epoch 336/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0539 - val_loss: 0.0711
# Epoch 337/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0516 - val_loss: 0.0890
# Epoch 338/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0544 - val_loss: 0.0738
# Epoch 339/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0511 - val_loss: 0.0948
# Epoch 340/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0518 - val_loss: 0.0791
# Epoch 341/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0516 - val_loss: 0.0839
# Epoch 342/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0533 - val_loss: 0.0837
# Epoch 343/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0515 - val_loss: 0.0790
# Epoch 344/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0467 - val_loss: 0.0776
# Epoch 345/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0511 - val_loss: 0.0900
# Epoch 346/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0492 - val_loss: 0.0789
# Epoch 347/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0504 - val_loss: 0.0863
# Epoch 348/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0495 - val_loss: 0.0806
# Epoch 349/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0501 - val_loss: 0.0744
# Epoch 350/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0464 - val_loss: 0.0855
# Epoch 351/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0469 - val_loss: 0.0760
# Epoch 352/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0466 - val_loss: 0.0804
# Epoch 353/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0447 - val_loss: 0.0865
# Epoch 354/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0459 - val_loss: 0.0885
# Epoch 355/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0465 - val_loss: 0.0979
# Epoch 356/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0466 - val_loss: 0.0725
# Epoch 357/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0456 - val_loss: 0.0892
# Epoch 358/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0434 - val_loss: 0.0955
# Epoch 359/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0460 - val_loss: 0.0911
# Epoch 360/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0486 - val_loss: 0.0882
# Epoch 361/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0432 - val_loss: 0.1178
# Epoch 362/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0460 - val_loss: 0.0831
# Epoch 363/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0472 - val_loss: 0.0976
# Epoch 364/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0477 - val_loss: 0.0792
# Epoch 365/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0455 - val_loss: 0.0793
# Epoch 366/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0423 - val_loss: 0.0760
# Epoch 367/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0432 - val_loss: 0.1030
# Epoch 368/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0496 - val_loss: 0.1076
# Epoch 369/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0499 - val_loss: 0.0870
# Epoch 370/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0464 - val_loss: 0.0821
# Epoch 371/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0479 - val_loss: 0.0854
# Epoch 372/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0460 - val_loss: 0.0863
# Epoch 373/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0445 - val_loss: 0.0989
# Epoch 374/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0438 - val_loss: 0.0839
# Epoch 375/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0446 - val_loss: 0.0846
# Epoch 376/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0441 - val_loss: 0.1004
# Epoch 377/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0448 - val_loss: 0.0715
# Epoch 378/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0459 - val_loss: 0.0857
# Epoch 379/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0469 - val_loss: 0.1052
# Epoch 380/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0429 - val_loss: 0.0949
# Epoch 381/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0415 - val_loss: 0.1000
# Epoch 382/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0480 - val_loss: 0.0752
# Epoch 383/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0429 - val_loss: 0.0943
# Epoch 384/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0424 - val_loss: 0.0739
# Epoch 385/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0406 - val_loss: 0.0755
# Epoch 386/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0473 - val_loss: 0.0827
# Epoch 387/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0445 - val_loss: 0.0645
# Epoch 388/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0458 - val_loss: 0.0781
# Epoch 389/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0436 - val_loss: 0.0876
# Epoch 390/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0430 - val_loss: 0.0629
# Epoch 391/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0432 - val_loss: 0.0881
# Epoch 392/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0415 - val_loss: 0.0836
# Epoch 393/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0415 - val_loss: 0.0745
# Epoch 394/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0391 - val_loss: 0.0780
# Epoch 395/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0415 - val_loss: 0.0701
# Epoch 396/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0406 - val_loss: 0.0850
# Epoch 397/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0402 - val_loss: 0.0934
# Epoch 398/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0410 - val_loss: 0.0825
# Epoch 399/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0407 - val_loss: 0.1065
# Epoch 400/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0394 - val_loss: 0.0963
# Epoch 401/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0419 - val_loss: 0.1448
# Epoch 402/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0413 - val_loss: 0.1471
# Epoch 403/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0401 - val_loss: 0.1427
# Epoch 404/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0408 - val_loss: 0.1310
# Epoch 405/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0391 - val_loss: 0.1476
# Epoch 406/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0381 - val_loss: 0.1066
# Epoch 407/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0427 - val_loss: 0.1403
# Epoch 408/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0404 - val_loss: 0.1199
# Epoch 409/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0399 - val_loss: 0.1124
# Epoch 410/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0425 - val_loss: 0.1037
# Epoch 411/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0383 - val_loss: 0.0730
# Epoch 412/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0399 - val_loss: 0.0984
# Epoch 413/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0380 - val_loss: 0.1076
# Epoch 414/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0392 - val_loss: 0.0988
# Epoch 415/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0372 - val_loss: 0.1207
# Epoch 416/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0384 - val_loss: 0.1138
# Epoch 417/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0370 - val_loss: 0.0885
# Epoch 418/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0388 - val_loss: 0.1129
# Epoch 419/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0380 - val_loss: 0.1025
# Epoch 420/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0373 - val_loss: 0.0921
# Epoch 421/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0374 - val_loss: 0.1134
# Epoch 422/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0362 - val_loss: 0.0936
# Epoch 423/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0371 - val_loss: 0.1150
# Epoch 424/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0370 - val_loss: 0.1165
# Epoch 425/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0408 - val_loss: 0.1157
# Epoch 426/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0379 - val_loss: 0.1559
# Epoch 427/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0376 - val_loss: 0.1566
# Epoch 428/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0393 - val_loss: 0.1709
# Epoch 429/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0372 - val_loss: 0.1270
# Epoch 430/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0362 - val_loss: 0.1110
# Epoch 431/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0386 - val_loss: 0.0995
# Epoch 432/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0412 - val_loss: 0.0885
# Epoch 433/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0374 - val_loss: 0.1296
# Epoch 434/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0370 - val_loss: 0.1110
# Epoch 435/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0369 - val_loss: 0.1248
# Epoch 436/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0383 - val_loss: 0.1006
# Epoch 437/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0402 - val_loss: 0.1424
# Epoch 438/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0362 - val_loss: 0.1457
# Epoch 439/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0370 - val_loss: 0.1116
# Epoch 440/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0360 - val_loss: 0.1278
# Epoch 441/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0367 - val_loss: 0.0777
# Epoch 442/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0364 - val_loss: 0.0976
# Epoch 443/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0383 - val_loss: 0.0888
# Epoch 444/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0338 - val_loss: 0.1258
# Epoch 445/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0370 - val_loss: 0.1143
# Epoch 446/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0375 - val_loss: 0.1159
# Epoch 447/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0336 - val_loss: 0.0829
# Epoch 448/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0350 - val_loss: 0.0902
# Epoch 449/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0355 - val_loss: 0.0824
# Epoch 450/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0404 - val_loss: 0.1125
# Epoch 451/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0370 - val_loss: 0.1311
# Epoch 452/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0331 - val_loss: 0.1257
# Epoch 453/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0355 - val_loss: 0.0902
# Epoch 454/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0393 - val_loss: 0.1321
# Epoch 455/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0368 - val_loss: 0.0903
# Epoch 456/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0330 - val_loss: 0.1150
# Epoch 457/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0350 - val_loss: 0.0909
# Epoch 458/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0330 - val_loss: 0.0836
# Epoch 459/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0334 - val_loss: 0.1020
# Epoch 460/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0324 - val_loss: 0.0921
# Epoch 461/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0383 - val_loss: 0.0790
# Epoch 462/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0353 - val_loss: 0.0699
# Epoch 463/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0349 - val_loss: 0.0743
# Epoch 464/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0333 - val_loss: 0.0849
# Epoch 465/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0334 - val_loss: 0.0961
# Epoch 466/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0327 - val_loss: 0.1399
# Epoch 467/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0481 - val_loss: 0.1553
# Epoch 468/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0404 - val_loss: 0.0985
# Epoch 469/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0381 - val_loss: 0.1350
# Epoch 470/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0368 - val_loss: 0.1033
# Epoch 471/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0342 - val_loss: 0.1217
# Epoch 472/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0333 - val_loss: 0.1117
# Epoch 473/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0357 - val_loss: 0.1039
# Epoch 474/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0344 - val_loss: 0.1077
# Epoch 475/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0336 - val_loss: 0.0901
# Epoch 476/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0319 - val_loss: 0.1016
# Epoch 477/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0333 - val_loss: 0.0811
# Epoch 478/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0336 - val_loss: 0.1011
# Epoch 479/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0336 - val_loss: 0.1116
# Epoch 480/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0335 - val_loss: 0.1124
# Epoch 481/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0334 - val_loss: 0.1018
# Epoch 482/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0314 - val_loss: 0.1243
# Epoch 483/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0315 - val_loss: 0.1182
# Epoch 484/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0304 - val_loss: 0.1104
# Epoch 485/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0295 - val_loss: 0.1302
# Epoch 486/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0336 - val_loss: 0.0978
# Epoch 487/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0321 - val_loss: 0.1029
# Epoch 488/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0334 - val_loss: 0.0852
# Epoch 489/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0325 - val_loss: 0.1056
# Epoch 490/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0323 - val_loss: 0.1236
# Epoch 491/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0304 - val_loss: 0.1209
# Epoch 492/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0322 - val_loss: 0.1481
# Epoch 493/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0349 - val_loss: 0.0960
# Epoch 494/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0323 - val_loss: 0.1106
# Epoch 495/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0321 - val_loss: 0.0881
# Epoch 496/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0310 - val_loss: 0.1067
# Epoch 497/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0333 - val_loss: 0.1057
# Epoch 498/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0341 - val_loss: 0.0781
# Epoch 499/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0324 - val_loss: 0.0870
# Epoch 500/500
# 11/11 [==============================] - 12s 1s/step - loss: 0.0339 - val_loss: 0.0696

# %%
def get_output(model, preproc, image_path, output_path):
     origin_img = imread(image_path)
     data = {"image":origin_img}
     processed = preproc(**data)
     output = model(np.expand_dims(processed["image"]/255,axis=0))
     output = (output[0].numpy()>0.5).astype(np.uint8).squeeze(-1)*255  #0.5라는 threshold를 변경하면 도로인식 결과범위가 달라집니다.
     output = Image.fromarray(output)
     background = Image.fromarray(origin_img).convert('RGBA')
     output = output.resize((origin_img.shape[1], origin_img.shape[0])).convert('RGBA')
     output = Image.blend(background, output, alpha=0.5)
     output.show()
     return output

# %%
i = 3    # change i for different data. 
get_output(
     model, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png'
 )
# Out:
# <PIL.Image.Image image mode=RGBA size=1242x375 at 0x2C50783A0>

# %%
def calculate_iou_score(target, prediction):
    intersection = np.logical_and(target, prediction)
    union = np.logical_or(target, prediction)
    iou_score = float(np.sum(intersection)) / float(np.sum(union))
    print('IoU : %f' % iou_score )
    return iou_score

def get_output(model, preproc, image_path, output_path, label_path):
    origin_img = imread(image_path)
    data = {"image":origin_img}
    processed = preproc(**data)
    output = model(np.expand_dims(processed["image"]/255,axis=0))
    output = (output[0].numpy()>=0.5).astype(np.uint8).squeeze(-1)*255  #0.5라는 threshold를 변경하면 도로인식 결과범위가 달라집니다.
    prediction = output/255   # 도로로 판단한 영역
    
    output = Image.fromarray(output)
    background = Image.fromarray(origin_img).convert('RGBA')
    output = output.resize((origin_img.shape[1], origin_img.shape[0])).convert('RGBA')
    output = Image.blend(background, output, alpha=0.5)
    output.show()   # 도로로 판단한 영역을 시각화!
     
    if label_path:   
        label_img = imread(label_path)
        label_data = {"image":label_img}
        label_processed = preproc(**label_data)
        label_processed = label_processed["image"]
        target = (label_processed == 7).astype(np.uint8)*1   # 라벨에서 도로로 기재된 영역

        return output, prediction, target
    else:
        return output, prediction, _

# %%
# 완성한 뒤에는 시각화한 결과를 눈으로 확인해봅시다!
i = 1    # i값을 바꾸면 테스트용 파일이 달라집니다. 
output, prediction, target = get_output(
     model, 
     test_preproc,
     image_path=dir_path + f'/image_2/00{str(i).zfill(4)}_10.png',
     output_path=dir_path + f'./result_{str(i).zfill(3)}.png',
     label_path=dir_path + f'/semantic/00{str(i).zfill(4)}_10.png'
 )

calculate_iou_score(target, prediction)
# Out:
# IoU : 0.444763
# 0.4447632711621234

# %% [markdown]
# ## kitti dataset score
#
# |STD U-net|U-net++|U-net++ W/ 500epochs|
# |------|---|---|
# |0.44|0.53|0.44|
#
# U-net++ 모델을 사용한 결과 동일한 에폭에서는 ++가 더욱 좋은 성능을 보여주었지만 에폭을 추가했을때는 좋지못한 성능을 보여주고있습니다. 앞으로 DeepLab이나 mask RCNN같은 다른 네트워크를 직접 구현해서 성능을 비교하여 장단점을 정리해보도록 해야겠습니다.
